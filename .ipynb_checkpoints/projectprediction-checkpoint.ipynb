# %%
import pandas as pd
import numpy as np

# %%
matches=pd.read_csv("IPL_Matches_2008_2022.csv")
ball=pd.read_csv("IPL_Ball_by_Ball_2008_2022.csv")

# %%
matches_detail=matches.merge(ball,on="ID")

# %%
matches_detail["Team1"]=matches_detail["Team1"].str.replace("Deccan Chargers","Sunrisers Hyderabad")
matches_detail["Team2"]=matches_detail["Team2"].str.replace("Deccan Chargers","Sunrisers Hyderabad")
matches_detail["Team1"]=matches_detail["Team1"].str.replace("Delhi Daredevils","Delhi Capital")
matches_detail["Team2"]=matches_detail["Team2"].str.replace("Delhi Daredevils","Delhi Capital")
matches_detail["Team1"]=matches_detail["Team1"].str.replace("Kings XI Punjab","Punjab Kings")
matches_detail["Team2"]=matches_detail["Team2"].str.replace("Kings XI Punjab","Punjab Kings")
matches_detail["City"]=matches_detail["City"].str.replace("Bangalore","Bengaluru")

# %%
matches_detail.iloc[1]
# Out:
# ID                                                             1312200
# City                                                         Ahmedabad
# Date                                                        2022-05-29
# Season                                                            2022
# MatchNumber                                                      Final
# Team1                                                 Rajasthan Royals
# Team2                                                   Gujarat Titans
# Venue                                 Narendra Modi Stadium, Ahmedabad
# TossWinner                                            Rajasthan Royals
# TossDecision                                                       bat
# SuperOver                                                            N
# WinningTeam                                             Gujarat Titans
# WonBy                                                          Wickets
# Margin                                                             7.0
# method                                                             NaN
# Player_of_Match                                              HH Pandya
# Team1Players         ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# Team2Players         ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...
# Umpire1                                                    CB Gaffaney
# Umpire2                                                    Nitin Menon
# innings                                                              1
# overs                                                                0
# ballnumber                                                           2
# batter                                                     YBK Jaiswal
# bowler                                                  Mohammed Shami
# non-striker                                                 JC Buttler
# extra_type                                                     legbyes
# batsman_run                                                          0
# extras_run                                                           1
# total_run                                                            1
# non_boundary                                                         0
# isWicketDelivery                                                     0
# player_out                                                         NaN
# kind                                                               NaN
# fielders_involved                                                  NaN
# BattingTeam                                           Rajasthan Royals
# Name: 1, dtype: object

# %%
matches_detail
# Out:
#              ID       City        Date   Season MatchNumber  \
# 0       1312200  Ahmedabad  2022-05-29     2022       Final
# 1       1312200  Ahmedabad  2022-05-29     2022       Final
# 2       1312200  Ahmedabad  2022-05-29     2022       Final
# 3       1312200  Ahmedabad  2022-05-29     2022       Final
# 4       1312200  Ahmedabad  2022-05-29     2022       Final
# ...         ...        ...         ...      ...         ...
# 225949   335982  Bengaluru  2008-04-18  2007/08           1
# 225950   335982  Bengaluru  2008-04-18  2007/08           1
# 225951   335982  Bengaluru  2008-04-18  2007/08           1
# 225952   335982  Bengaluru  2008-04-18  2007/08           1
# 225953   335982  Bengaluru  2008-04-18  2007/08           1
#
#                               Team1                  Team2  \
# 0                  Rajasthan Royals         Gujarat Titans
# 1                  Rajasthan Royals         Gujarat Titans
# 2                  Rajasthan Royals         Gujarat Titans
# 3                  Rajasthan Royals         Gujarat Titans
# 4                  Rajasthan Royals         Gujarat Titans
# ...                             ...                    ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                    Venue                   TossWinner  \
# 0       Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1       Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2       Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 3       Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 4       Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# ...                                  ...                          ...
# 225949             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225950             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225951             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225952             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225953             M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#        TossDecision  ... extra_type batsman_run extras_run  total_run  \
# 0               bat  ...        NaN           0          0          0
# 1               bat  ...    legbyes           0          1          1
# 2               bat  ...        NaN           1          0          1
# 3               bat  ...        NaN           0          0          0
# 4               bat  ...        NaN           0          0          0
# ...             ...  ...        ...         ...        ...        ...
# 225949        field  ...    legbyes           0          1          1
# 225950        field  ...        NaN           1          0          1
# 225951        field  ...        NaN           0          0          0
# 225952        field  ...      wides           0          1          1
# 225953        field  ...        NaN           0          0          0
#
#        non_boundary isWicketDelivery player_out    kind fielders_involved  \
# 0                 0                0        NaN     NaN               NaN
# 1                 0                0        NaN     NaN               NaN
# 2                 0                0        NaN     NaN               NaN
# 3                 0                0        NaN     NaN               NaN
# 4                 0                0        NaN     NaN               NaN
# ...             ...              ...        ...     ...               ...
# 225949            0                0        NaN     NaN               NaN
# 225950            0                0        NaN     NaN               NaN
# 225951            0                0        NaN     NaN               NaN
# 225952            0                0        NaN     NaN               NaN
# 225953            0                1   SB Joshi  caught       BB McCullum
#
#                         BattingTeam
# 0                  Rajasthan Royals
# 1                  Rajasthan Royals
# 2                  Rajasthan Royals
# 3                  Rajasthan Royals
# 4                  Rajasthan Royals
# ...                             ...
# 225949  Royal Challengers Bangalore
# 225950  Royal Challengers Bangalore
# 225951  Royal Challengers Bangalore
# 225952  Royal Challengers Bangalore
# 225953  Royal Challengers Bangalore
#
# [225954 rows x 36 columns]

# %%
team=["Chennai Super Kings","Delhi Capitals","Gujarat Titans","Punjab Kings","Lucknow Super Giants","Mumbai Indians","Kolkata Knight Riders","Rajasthan Royals","Royal Challengers Bangalore","Sunrisers Hyderabad"]

# %%
matches_detail=matches_detail[(matches_detail["Team1"].isin(team)) & (matches_detail["Team2"].isin(team) )]

# %%
total_score=matches_detail.groupby(["ID","innings"])["total_run"].sum()
total_score=total_score.reset_index()
ts=total_score[total_score["innings"]==1]

# %%
matches_detail=matches_detail[matches_detail["innings"]==2]

# %%
matches_detail=matches_detail.merge(ts,on="ID")

# %%
matches_detail["runs"]=matches_detail.groupby("ID")["total_run_x"].cumsum()

# %%
matches_detail["runs_left"]=matches_detail["total_run_y"]-matches_detail["runs"]

# %%
matches_detail=matches_detail[matches_detail["runs_left"]>=0]

# %%
def result(row):
    return 1 if row["BattingTeam"]==row["WinningTeam"] else 0

# %%
matches_detail["result"]=matches_detail.apply(result,axis=1)

# %%
matches_detail.sample()
# Out:
#            ID     City        Date Season MatchNumber           Team1  \
# 39912  829823  Kolkata  2015-05-24   2015       Final  Mumbai Indians
#
#                      Team2         Venue           TossWinner TossDecision  \
# 39912  Chennai Super Kings  Eden Gardens  Chennai Super Kings        field
#
#        ... isWicketDelivery player_out kind  fielders_involved  \
# 39912  ...                0        NaN  NaN                NaN
#
#                BattingTeam innings_y total_run_y runs runs_left result
# 39912  Chennai Super Kings         1         202   59       143      0
#
# [1 rows x 41 columns]

# %%
matches_detail["wickets_left"]=10-matches_detail.groupby("ID")["isWicketDelivery"].cumsum()

# %%
matches_detail[matches_detail["innings_x"]==1]
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2, innings_x, overs, ballnumber, batter, bowler, non-striker, extra_type, batsman_run, extras_run, total_run_x, non_boundary, isWicketDelivery, player_out, kind, fielders_involved, BattingTeam, innings_y, total_run_y, runs, runs_left, result, wickets_left]
# Index: []
#
# [0 rows x 42 columns]

# %%
ball
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# 0        JC Buttler        NaN            0           0          0
# 1        JC Buttler    legbyes            0           1          1
# 2       YBK Jaiswal        NaN            1           0          1
# 3        JC Buttler        NaN            0           0          0
# 4        JC Buttler        NaN            0           0          0
# ...             ...        ...          ...         ...        ...
# 225949     SB Joshi    legbyes            0           1          1
# 225950      P Kumar        NaN            1           0          1
# 225951     SB Joshi        NaN            0           0          0
# 225952      P Kumar      wides            0           1          1
# 225953      P Kumar        NaN            0           0          0
#
#         non_boundary  isWicketDelivery player_out    kind fielders_involved  \
# 0                  0                 0        NaN     NaN               NaN
# 1                  0                 0        NaN     NaN               NaN
# 2                  0                 0        NaN     NaN               NaN
# 3                  0                 0        NaN     NaN               NaN
# 4                  0                 0        NaN     NaN               NaN
# ...              ...               ...        ...     ...               ...
# 225949             0                 0        NaN     NaN               NaN
# 225950             0                 0        NaN     NaN               NaN
# 225951             0                 0        NaN     NaN               NaN
# 225952             0                 0        NaN     NaN               NaN
# 225953             0                 1   SB Joshi  caught       BB McCullum
#
#                         BattingTeam
# 0                  Rajasthan Royals
# 1                  Rajasthan Royals
# 2                  Rajasthan Royals
# 3                  Rajasthan Royals
# 4                  Rajasthan Royals
# ...                             ...
# 225949  Royal Challengers Bangalore
# 225950  Royal Challengers Bangalore
# 225951  Royal Challengers Bangalore
# 225952  Royal Challengers Bangalore
# 225953  Royal Challengers Bangalore
#
# [225954 rows x 17 columns]

# %%
matches_detail["balls_left"]=120-(matches_detail["overs"]*6+matches_detail["ballnumber"])

# %%
matches_detail=matches_detail[matches_detail["balls_left"]!=0]

# %%
matches_detail["CRR"]=matches_detail["runs"]*6/(120-matches_detail["balls_left"])

# %%
matches_detail["RRR"]=matches_detail["runs_left"]*6/(matches_detail["balls_left"])

# %%
def bowl(row):
    if row["BattingTeam"]!=row["Team1"]:
        return row["Team1"]
    else:
        return row["Team2"]

# %%
matches_detail["BowlingTeam"]=matches_detail.apply(bowl,axis=1)

# %%
matches_detail.iloc[170]
# Out:
# ID                                                             1312199
# City                                                         Ahmedabad
# Date                                                        2022-05-27
# Season                                                            2022
# MatchNumber                                                Qualifier 2
# Team1                                      Royal Challengers Bangalore
# Team2                                                 Rajasthan Royals
# Venue                                 Narendra Modi Stadium, Ahmedabad
# TossWinner                                            Rajasthan Royals
# TossDecision                                                     field
# SuperOver                                                            N
# WinningTeam                                           Rajasthan Royals
# WonBy                                                          Wickets
# Margin                                                             7.0
# method                                                             NaN
# Player_of_Match                                             JC Buttler
# Team1Players         ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# Team2Players         ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# Umpire1                                                    CB Gaffaney
# Umpire2                                                    Nitin Menon
# innings_x                                                            2
# overs                                                                9
# ballnumber                                                           5
# batter                                                      JC Buttler
# bowler                                                    PWH de Silva
# non-striker                                                  SV Samson
# extra_type                                                         NaN
# batsman_run                                                          1
# extras_run                                                           0
# total_run_x                                                          1
# non_boundary                                                         0
# isWicketDelivery                                                     0
# player_out                                                         NaN
# kind                                                               NaN
# fielders_involved                                                  NaN
# BattingTeam                                           Rajasthan Royals
# innings_y                                                            1
# total_run_y                                                        157
# runs                                                               103
# runs_left                                                           54
# result                                                               1
# wickets_left                                                         9
# balls_left                                                          61
# CRR                                                          10.474576
# RRR                                                           5.311475
# BowlingTeam                                Royal Challengers Bangalore
# Name: 171, dtype: object

# %%
final=matches_detail[["BattingTeam","BowlingTeam","City","runs_left","total_run_y","balls_left","wickets_left","CRR","RRR","result"]]

# %%
final
# Out:
#                        BattingTeam            BowlingTeam       City  \
# 0                   Gujarat Titans       Rajasthan Royals  Ahmedabad
# 1                   Gujarat Titans       Rajasthan Royals  Ahmedabad
# 2                   Gujarat Titans       Rajasthan Royals  Ahmedabad
# 3                   Gujarat Titans       Rajasthan Royals  Ahmedabad
# 4                   Gujarat Titans       Rajasthan Royals  Ahmedabad
# ...                            ...                    ...        ...
# 79828  Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
# 79829  Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
# 79830  Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
# 79831  Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
# 79832  Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
#
#        runs_left  total_run_y  balls_left  wickets_left       CRR        RRR  \
# 0            130          130         119            10  0.000000   6.554622
# 1            130          130         118            10  0.000000   6.610169
# 2            129          130         117            10  2.000000   6.615385
# 3            129          130         116            10  1.500000   6.672414
# 4            129          130         115            10  1.200000   6.730435
# ...          ...          ...         ...           ...       ...        ...
# 79828        142          222          31             1  5.393258  27.483871
# 79829        141          222          30             1  5.400000  28.200000
# 79830        141          222          29             1  5.340659  29.172414
# 79831        140          222          29             1  5.406593  28.965517
# 79832        140          222          28             0  5.347826  30.000000
#
#        result
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 79828       0
# 79829       0
# 79830       0
# 79831       0
# 79832       0
#
# [79208 rows x 10 columns]

# %%
x=final.iloc[:,:-1]
y=final.iloc[:,-1]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
pip install scikit-learn==1.5.0
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\~klearn'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn==1.5.0
#   Downloading scikit_learn-1.5.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\hpw\appdata\roaming\python\python311\site-packages (from scikit-learn==1.5.0) (1.25.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\hpw\appdata\roaming\python\python311\site-packages (from scikit-learn==1.5.0) (1.11.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hpw\appdata\roaming\python\python311\site-packages (from scikit-learn==1.5.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hpw\appdata\roaming\python\python311\site-packages (from scikit-learn==1.5.0) (3.2.0)
# Downloading scikit_learn-1.5.0-cp311-cp311-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB 1.4 MB/s eta 0:00:09
#    ---------------------------------------- 0.0/11.0 MB 1.4 MB/s eta 0:00:09
#    ---------------------------------------- 0.1/11.0 MB 544.7 kB/s eta 0:00:21
#    ---------------------------------------- 0.1/11.0 MB 585.1 kB/s eta 0:00:19
#    ---------------------------------------- 0.1/11.0 MB 554.9 kB/s eta 0:00:20
#     --------------------------------------- 0.2/11.0 MB 942.1 kB/s eta 0:00:12
#    - -------------------------------------- 0.3/11.0 MB 965.4 kB/s eta 0:00:12
#    - -------------------------------------- 0.4/11.0 MB 1.1 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/11.0 MB 1.1 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/11.0 MB 1.1 MB/s eta 0:00:10
#    -- ------------------------------------- 0.6/11.0 MB 1.2 MB/s eta 0:00:09
#    -- ------------------------------------- 0.6/11.0 MB 1.2 MB/s eta 0:00:09
#    -- ------------------------------------- 0.7/11.0 MB 1.2 MB/s eta 0:00:09
#    -- ------------------------------------- 0.8/11.0 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 0.9/11.0 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/11.0 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 1.1/11.0 MB 1.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.2/11.0 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.3/11.0 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.3/11.0 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.4/11.0 MB 1.5 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.4/11.0 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.5/11.0 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.6/11.0 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.6/11.0 MB 1.4 MB/s eta 0:00:07
#    ------ --------------------------------- 1.7/11.0 MB 1.4 MB/s eta 0:00:07
#    ------ --------------------------------- 1.8/11.0 MB 1.4 MB/s eta 0:00:07
#    ------ --------------------------------- 1.8/11.0 MB 1.4 MB/s eta 0:00:07
#    ------ --------------------------------- 1.9/11.0 MB 1.4 MB/s eta 0:00:07
#    ------------------------------- -------- 8.8/11.0 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 8.8/11.0 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 8.9/11.0 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 9.0/11.0 MB 1.7 MB/s eta 0:00:02
#    --------------------------------- ------ 9.1/11.0 MB 1.7 MB/s eta 0:00:02
#    --------------------------------- ------ 9.2/11.0 MB 1.7 MB/s eta 0:00:02
#    --------------------------------- ------ 9.2/11.0 MB 1.7 MB/s eta 0:00:02
#    --------------------------------- ------ 9.3/11.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.4/11.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.5/11.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.5/11.0 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.6/11.0 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.8/11.0 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.8/11.0 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.9/11.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 9.9/11.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 10.1/11.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 10.1/11.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/11.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/11.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 10.3/11.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 10.3/11.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 10.4/11.0 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/11.0 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/11.0 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 10.6/11.0 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 10.6/11.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  10.8/11.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  10.8/11.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  10.9/11.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 1.7 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.1
#     Uninstalling scikit-learn-1.2.1:
#       Successfully uninstalled scikit-learn-1.2.1
# Successfully installed scikit-learn-1.5.0

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf=ColumnTransformer([
    ("trf",OneHotEncoder(sparse=False,drop="first"),["BattingTeam","BowlingTeam","City"])
],remainder="passthrough")

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline(steps=[
    ("step1",trf),
    ("step2",LogisticRegression(solver="liblinear"))
])

# %%
pipe.fit(x_train,y_train)
# Out:
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['BattingTeam', 'BowlingTeam',
#                                                    'City'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred=pipe.predict(x_test)
# Out:
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# 0.8066532003534908

# %%
pipe.predict_proba(x_test)[170]
# Out:
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\HPW\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# array([0.60077757, 0.39922243])

# %%
import pickle

# %%
pickle.dump(pipe,open("pipe.pkl","wb"))

# %%
matches_detail["City"].unique()
# Out:
# array(['Ahmedabad', 'Kolkata', 'Mumbai', 'Navi Mumbai', 'Pune', 'Dubai',
#        'Sharjah', 'Abu Dhabi', 'Delhi', 'Chennai', nan, 'Hyderabad',
#        'Visakhapatnam', 'Chandigarh', 'Bengaluru', 'Jaipur', 'Indore',
#        'Bangalore', 'Ranchi', 'Cuttack', 'Dharamsala', 'Nagpur',
#        'Johannesburg', 'Centurion', 'Durban', 'Port Elizabeth',
#        'Kimberley', 'East London', 'Cape Town'], dtype=object)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.1
